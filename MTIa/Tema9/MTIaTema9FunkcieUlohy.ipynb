# %% [markdown]
# **Autor:** Andrej Gajdoš  <br>
# *[Ústav matematických vied](https://www.upjs.sk/prirodovedecka-fakulta/ustav/umv/), [Prírodovedecká fakulta](https://www.upjs.sk/prirodovedecka-fakulta/), Univerzita Pavla Jozefa Šafárika v Košiciach,* <br>
# email: [andrej.gajdos@upjs.sk](mailto:andrej.gajdos@upjs.sk)
# ***
# **_Tento materiál vznikol za podpory grantu VVGS-2021-1758._**
# ***
#
# **<font size=6 color=gold> MTIa: Téma 9 - Funkcie: úlohy </font>**

# %% [markdown]
# ---
#
# **$\clubsuit$ 1. V decembri 2010 bol úhrn snehových zrážok v Minneapolise nezvyčajne vysoký, čo viedlo k zrúteniu strechy Metrodome. Obrázok nižšie udáva úhrn snehových zrážok $S$ (v palcoch, $1$ palec $\doteq$ $2.54$ cm) v Minneapolise od 6. do 15. decembra 2010.**
#
# ![snezenie_Minneapolis.png](attachment:snezenie_Minneapolis.png)
# $$\text{Zdroj: Hallet (2017).}$$
#
# **a) Ako viete, že údaje o snehových zrážkach sú funkciou dátumu?**
#
# **b) Odhadnite úhrn snehových zrážok 12. decembra.**
#
# **c) Ktorý deň bol úhrn snehových zrážok viac ako $10$ palcov?**
#
# **d) Počas ktorých dvoch po sebe nasledujúcich dní bol najväcší nárast snehových zrážok?**

# %% [markdown]
# ---
#
# **$\clubsuit$ 2. V meste Kalifornia je mesačný poplatok za odvoz odpadu $8$ dolárov za $32$ galónov ($1$ galón $\approx$ $3.78$ kg) odpadu a $12.32$ dolárov za $68$ galónov odpadu.**
#
# **a) Nájdite predpis lineárnej funkcie, ktorá vyjadruje výdavky $C$ za odvoz odpadu v závislosti od množstva odpadu $w$ (v galónoch).**
#
# **b) Aký je sklon priamky (grafu funkcie)? Interpretujte to v správnych jednotkách a v kontexte úlohy.**
#
# **c) Aká je hodnota absolútneho člena (hodnota funkcie pre $x=0$) v predpise funkcie (priamky)? Interpretujte ho v správnych jednotkách a v kontexte úlohy.**

# %% [markdown]
# ---
#
# **$\clubsuit$ 3. Nájdite zložené funkcie $u\circ u,u\circ v,v\circ u,v\circ v$, ak $u:\ y=\frac{x+1}{x-1}$ a $v:\ y=\sqrt{x}$.** Nezabudnite určiť definičné obory i obory hodnôt pôvodných funkcií aj zloženej funkcie (kvôli lepšej predstave môžete vykresliť grafy v Sage).

# %% [markdown]
# ---
#
# **4. Vyjadrite každú z nasledujúcich funkcií ako zloženú funkciu (kompozíciu):**
#
# $ \clubsuit\, \text{a) }\, h(t)=\left(1+t^3\right)^{27}, \qquad\qquad \text{b) }\, k(y)=e^{-y^2}, \qquad\qquad \text{c) }\, l(y)=-\left(e^y\right)^2$.

# %% [markdown]
# ---
#
# **$\clubsuit$ 5. Na základe grafov určte približne nasledujúce hodnoty: $f(g(1))$, $g(f(2))$, $f(f(1))$.**
#
# ![skladanie_funkcii_grafy.png](attachment:skladanie_funkcii_grafy.png)
# $$\text{Zdroj: Hallet (2017).}$$

# %% [markdown]
# ---
#
# **6. Určte definičný obor funkcie $f$ danej predpisom:**
#
# $ \clubsuit\, \text{a) }\,y=\sqrt{\frac{x+1}{x-3}-\frac{x-2}{x+4}},\qquad\qquad \clubsuit\, \text{b) }\, y=\sqrt{\ln(\frac{5x-x^2}{4})}, \qquad\qquad \text{c) }\, y=\arcsin \frac{2x}{1+x}, \qquad\qquad \text{d) }\, y=\frac{\ln\frac{3-4x}{x+2}}{x}.$

# %% [markdown]
# ---
#
# **7. Zistite, či sa funkcie $f:\ y=\frac{\frac{1}{1-x}-1}{x-\frac{1-2x^2}{1-x}+1}$ a $g:\ y=\frac{1}{x}$ rovnajú. Ak nie, nájdite maximálnu podmnožinu $\mathbb{R}$, na ktorej $f(x)=g(x)$.**

# %% [markdown]
# ---
#
# **8. Zistite, či je daná funkcia párna, nepárna alebo ani párna, ani nepárna.**
#
# $\text{a) }\,e:\ y=\frac{1}{2x}\qquad\qquad \clubsuit\,\text{b) }\,f:\ y=x^2 -x+1, \qquad\qquad \clubsuit\,\text{c) }\,g:\ y=\ln\frac{4-x}{4+x} \qquad\qquad \text{d) }\,h:\ y=\frac{x^4 -1}{x-1}$.

# %% [markdown]
# ---
#
# **9. Vyšetrite monotónnosť (resp. rýdzomonotónnosť) funkcie:**
#
# $\clubsuit\, \text{a) }\, e:\ y=2-7x, \qquad\qquad \text{b) }\, f:\ y=\sqrt{2-3x}, \qquad\qquad \text{c) }\, g:\ y=x^3 -x, \qquad\qquad \clubsuit\, \text{d) }\, h:\ y=\frac{2+x}{3-x}$.

# %% [markdown]
# ----
#
# **$\clubsuit$ 10. Overte, či je funkcia na svojom definičnom obore prostá. Ak áno, nájdite k nej inverznú funkciu.**
#
# $\text{a) }\, e:\ y=x^2 -2, \qquad\qquad \text{b) }\, f:\ y=2+3\sqrt{x}$.

# %% [markdown]
# ---
#
# **$\clubsuit$ 11. Ukážte, že funkcia $f:\ y=\frac{1}{4+x^2}$ je na $\mathbb{R}$ ohraničená.**

# %% [markdown]
# ---
#
# **12. Dokážte, že funkcia $f:\ y=3\cos(4x)$ je periodická a nájdite periódu (ak existuje).**

# %% [markdown]
# ---
#
# **13. Nájdite inverznú funkciu k:**
#
# $\text{a) }\, e:\ y=\frac{x^3}{x^3 +1}, \qquad\qquad \text{b) }\, f:\ y=\frac{2+x}{3-x}, \qquad\qquad \text{c) }\, g:\ y=\cos\left(\ln\left(\frac{3x-1}{2}\right)\right), \qquad\qquad \text{d) }\, h:\ y=\sqrt[n]{a-x^n},\ x>0$.

# %% [markdown]
# ---
#
# **$\clubsuit$ 14. Je daný graf funkcie:**
#
# ![graf_f_vlastnosti_uloha.PNG](attachment:graf_f_vlastnosti_uloha.PNG)
#
# **a) V ktorých bodoch má funkcia lokálne maximum? Aké sú hodnoty lokálnych maxím?**
#
# **b) V ktorých bodoch má funkcia lokálne minimum? Aké sú hodnoty lokálnych miním?**
#
# **c) Na ktorých intervaloch je funkcia rastúca a kde je klesajúca?**
